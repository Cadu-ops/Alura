# %% [markdown]
# Entendendo o problema

# %%
import pandas as pd
import numpy as np
import json

# %%
dados = pd.read_json('dados/dataset-telecon.json')

# %%
dados.head()
# Out:
#    id_cliente Churn                                            cliente  \
# 0  0002-ORFBO   nao  {'genero': 'feminino', 'idoso': 0, 'parceiro':...
# 1  0003-MKNFE   nao  {'genero': 'masculino', 'idoso': 0, 'parceiro'...
# 2  0004-TLHLJ   sim  {'genero': 'masculino', 'idoso': 0, 'parceiro'...
# 3  0011-IGKFF   sim  {'genero': 'masculino', 'idoso': 1, 'parceiro'...
# 4  0013-EXCHZ   sim  {'genero': 'feminino', 'idoso': 1, 'parceiro':...
#
#                                             telefone  \
# 0  {'servico_telefone': 'sim', 'varias_linhas': '...
# 1  {'servico_telefone': 'sim', 'varias_linhas': '...
# 2  {'servico_telefone': 'sim', 'varias_linhas': '...
# 3  {'servico_telefone': 'sim', 'varias_linhas': '...
# 4  {'servico_telefone': 'sim', 'varias_linhas': '...
#
#                                             internet  \
# 0  {'servico_internet': 'DSL', 'seguranca_online'...
# 1  {'servico_internet': 'DSL', 'seguranca_online'...
# ...

# %%
pd.json_normalize(dados['conta']).head()
# Out:
#     contrato faturamente_eletronico     metodo_pagamento  cobranca.mensal  \
# 0        NaN                    NaN                  NaN              NaN
# 1  mes a mes                    nao  cheque pelo correio             59.9
# 2  mes a mes                    sim    cheque eletronico             73.9
# 3  mes a mes                    sim    cheque eletronico             98.0
# 4  mes a mes                    sim  cheque pelo correio             83.9
#
#   cobranca.Total
# 0            NaN
# 1          542.4
# 2         280.85
# 3        1237.85
# 4          267.4

# %%
with open('dados/dataset-telecon.json') as f:
    json_bruto = json.load(f)

# %%
dados_normalizados = pd.json_normalize(json_bruto)

# %%
dados_normalizados.head()
# Out:
#    id_cliente Churn cliente.genero  cliente.idoso cliente.parceiro  \
# 0  0002-ORFBO   nao       feminino              0              sim
# 1  0003-MKNFE   nao      masculino              0              nao
# 2  0004-TLHLJ   sim      masculino              0              nao
# 3  0011-IGKFF   sim      masculino              1              sim
# 4  0013-EXCHZ   sim       feminino              1              sim
#
#   cliente.dependentes  cliente.tempo_servico telefone.servico_telefone  \
# 0                 sim                    9.0                       sim
# 1                 nao                    9.0                       sim
# 2                 nao                    4.0                       sim
# 3                 nao                   13.0                       sim
# 4                 nao                    3.0                       sim
#
#   telefone.varias_linhas internet.servico_internet  ...  \
# 0                    nao                       DSL  ...
# ...

# %%
dados_normalizados.info()
# Out:
# <class 'pandas.DataFrame'>
# RangeIndex: 7344 entries, 0 to 7343
# Data columns (total 21 columns):
#  #   Column                         Non-Null Count  Dtype
# ---  ------                         --------------  -----
#  0   id_cliente                     7344 non-null   str
#  1   Churn                          7344 non-null   str
#  2   cliente.genero                 7344 non-null   str
#  3   cliente.idoso                  7344 non-null   int64
#  4   cliente.parceiro               7344 non-null   str
#  5   cliente.dependentes            7344 non-null   str
#  6   cliente.tempo_servico          7336 non-null   float64
#  7   telefone.servico_telefone      7344 non-null   str
#  8   telefone.varias_linhas         7344 non-null   str
#  9   internet.servico_internet      7344 non-null   str
#  10  internet.seguranca_online      7344 non-null   str
#  11  internet.backup_online         7344 non-null   str
#  12  internet.protecao_dispositivo  7344 non-null   str
# ...

# %%
dados_normalizados['conta.cobranca.Total'] = dados_normalizados['conta.cobranca.Total'].fillna('0')

# %%
idx = dados_normalizados[dados_normalizados['conta.cobranca.Total'] == ' '].index

# %%
idx
# Out:
# Index([975, 1775, 1955, 2075, 2232, 2308, 2930, 3134, 3203, 4169, 5599], dtype='int64')

# %%
dados_normalizados.loc[idx, 'conta.cobranca.Total'] = dados_normalizados.loc[idx, 'conta.cobranca.mensal'] * 24
# Out:
# ---------------------------------------------------------------------------
# TypeError                                 Traceback (most recent call last)
# Cell In[29], line 1
# ----> 1 dados_normalizados.loc[idx, 'conta.cobranca.Total'] = dados_normalizados.loc[idx, 'conta.cobranca.mensal'] * 24
#
# File c:\Users\logistica.wms\AppData\Local\Programs\Python\Python314\Lib\site-packages\pandas\core\indexing.py:938, in _LocationIndexer.__setitem__(self, key, value)
#     933 self._has_valid_setitem_indexer(key)
#     935 iloc: _iLocIndexer = (
#     936     cast("_iLocIndexer", self) if self.name == "iloc" else self.obj.iloc
#     937 )
# --> 938 iloc._setitem_with_indexer(indexer, value, self.name)
#
# File c:\Users\logistica.wms\AppData\Local\Programs\Python\Python314\Lib\site-packages\pandas\core\indexing.py:1953, in _iLocIndexer._setitem_with_indexer(self, indexer, value, name)
#    1950 # align and set the values
#    1951 if take_split_path:
# ...
